# %% [markdown]
# # Chapter 1 :: Hello Transformers
#
# ## Introduction
#
# In 2017, researchers at Google published a paper that proposed a novel neural network architecture for sequence modeling. Dubbed the **Transformer**, this architecture outperformed recurrent neural network (RNNs) on machine translation tasks, both in termsof translation quality and training cost.
